# %% [markdown]
# #### Classes and objects

# %%
class Car:
    pass

audi = Car()
bmw = Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
dir(audi)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
# __init__ is a contructor method

class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def bark(self):
        print("Bow wow bow wow!")
    

dog1 = Dog("Dodo", 4)
print(dog1)
dog1.bark()
# Out:
# ...
# Bow wow bow wow!

# %% [markdown]
# ### Inheritance

# %%
class Car:
    def __init__(self, windows, doors, enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype

    def drive(self):
        print(f"The person will drive car {self.enginetype} car");

# %%
car1 = Car(4, 5, "petrol")
car1.drive()
# Out:
# The person will drive car petrol car

# %%
class Tesla(Car):
    def __init__(self, windows, doors, enginetype, is_selfdriving):
        super().__init__(windows, doors, enginetype)
        self.is_selfdriving = is_selfdriving

    def selfdriving(self):
        print(f"Tesla supports self driving: {self.is_selfdriving}")

# %%
tesla1 = Tesla(4, 5, "electric", True)
tesla1.selfdriving()
tesla1.drive()
# Out:
# Tesla supports self driving: True
# The person will drive car electric car

# %%
# Multiple Inheritance

class Animal:
    def __init__(self, name):
        self.name = name
    
    def speak(self):
        print("subclasses must implement this method")

class Pet:
    def __init__(self, owner):
        self.owner = owner

class Dog(Animal, Pet):
    def __init__(self, name, owner):
        Animal.__init__(self, name)
        Pet.__init__(self, owner)
    
    def speak(self):
        print(f"{self.name} says woof!!!")

dog1 = Dog("Coco", "Trupti")
dog1.speak()
# Out:
# Coco says woof!!!

# %% [markdown]
# ### Polymorphism
#
# Allows objects of different classes to be treated as objects of a common superclass. It provides a way to perform a single action in different forms. Polymorphism is typically achieved through method overriding and interfaces.

# %% [markdown]
# #### Method overriding
# Allows a chile to provide a specific implementation of a method that is already defined by it's parent class.

# %%
class Animal:
    def speak(self):
        return "Sound of the animal"
    
class Dog(Animal):
    def speak(self):
        return "Woof!"
    
class Cat(Animal):
    def speak(self):
        return "Meow!"
    
# Function that demonstrates polymorphism
def animal_speak(animal):
    print(animal.speak())

dog = Dog()
print(dog.speak())

cat = Cat()
animal_speak(cat)
# Out:
# Woof!
# Meow!

# %%
# Polymorphism with functions and methods
from math import pi
class Shape:
    def area(self):
        return "Area of the figure"
    
class Reactangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height
    
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return pi * self.radius * self.radius
    
def print_area(shape):
    print(f"The area is {shape.area()}")

rectangle = Reactangle(4, 5)
circle = Circle(5)

print_area(rectangle)
print_area(circle)
# Out:
# The area is 20
# The area is 78.53981633974483

# %% [markdown]
# #### Polymorphism with abstract base class (ABCs)
# Similar to a interface

# %%
from abc import ABC, abstractmethod

# Define abstract class
class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        return "Car engine started!"
    
class Motorcycle(Vehicle):
    def start_engine(self):
        return "Motorcycle engine started!"

def start_vehicle(vehicle):
    print(vehicle.start_engine())    

car = Car()
motorcycle = Motorcycle()
start_vehicle(car)
start_vehicle(motorcycle)
# Out:
# Car engine started!
# Motorcycle engine started!

# %% [markdown]
# ### Encapsulation
#
# Encapsulation is the concept of wrapping data (variables) and methods (functions) together as a single unit. It restricts direct access to some of the objects's components, which is a means of preventing accidental interface of misuse of the data.

# %%
# Encapsulation with Getter and setter methods
# Public, private and protected variables

class Person:
    def __init__(self, name, age):
        self.name = name # public variable
        self.age = age # public

person = Person("Trupti", 21)
print(person.name)
# Out:
# Trupti

# %%
class Person:
    def __init__(self, name, age):
        self.__name = name # private variable (cannot access from outside as well as derived class)
        self._age = age # protected (cannot access from outside the class)

    def get_name(self):
        return self.__name
    
    def get_age(self):
        return self.__age
    
    def set_name(self, name):
        self.__name = name
    
    def set_age(self, age):
        self.__age = age

# %%
class Employee(Person):
    def __init__(self, name, age):
        super().__init__(name, age)

employee = Employee("Trupti", 21)
print(employee._age)
# Out:
# 21

# %% [markdown]
# #### Abstraction
# It is the concept of hidiing the complex implementation details and showing only the necessary feature of an object.

# %%
from abc import ABC, abstractmethod

# Abstract class
class Vehicle(ABC):
    def drive(self):
        print("The vehicle is used for driving")
    
    @abstractmethod
    def start_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        return "Engine is started!"
