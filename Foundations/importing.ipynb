# %% [markdown]
# #### How to import normal packages

# %%
import numpy as np
np.array([1, 2, 3, 4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
print(sqrt(2))
# Out:
# 1.4142135623730951

# %% [markdown]
# #### Importing from local packages

# %%
from package.maths import addition
addition(6, 7)
# Out:
# 13

# %%
from package import maths
maths.addition(56, 34)
# Out:
# 90
